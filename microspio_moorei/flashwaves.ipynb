# %%
println("Hola desde Julia")
2 + 3
# Out:
# Hola desde Julia
# 5

# %%
# using Pkg
# Pkg.add("FlashWeave")
using flashWeave
# Out:
#     Updating registry at `C:\Users\jupas\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed IrrationalConstants ───── v0.2.4
#    Installed ArnoldiMethod ─────────── v0.4.0
#    Installed XML2_jll ──────────────── v2.13.8+0
#    Installed libaec_jll ────────────── v1.1.4+0
#    Installed Rmath ─────────────────── v0.8.0
#    Installed MPICH_jll ─────────────── v4.3.1+0
#    Installed JLD2 ──────────────────── v0.4.54
#    Installed Xorg_libpciaccess_jll ─── v0.18.1+0
#    Installed HypergeometricFunctions ─ v0.3.28
#    Installed FlashWeave ────────────── v0.19.2
#    Installed StatsFuns ─────────────── v1.5.0
#    Installed PtrArrays ─────────────── v1.3.0
#    Installed Inflate ───────────────── v0.1.5
#    Installed OpenSSL_jll ───────────── v3.5.2+0
#    Installed Hwloc_jll ─────────────── v2.12.2+0
#    Installed SimpleWeightedGraphs ──── v1.5.0
#    Installed PDMats ────────────────── v0.11.35
#    Installed SpecialFunctions ──────── v2.5.1
# ...

# %%
cd("G:\\.shortcut-targets-by-id\\1mcz8n1CY2o_EnrBAWzPKDRdvU1kXRRHc\\MicrobiomaPolyqueto")
pwd()  # confirma que cambió
# Out:
# "G:\\.shortcut-targets-by-id\\1mcz8n1CY2o_EnrBAWzPKDRdvU1kXRRHc\\MicrobiomaPolyqueto"
